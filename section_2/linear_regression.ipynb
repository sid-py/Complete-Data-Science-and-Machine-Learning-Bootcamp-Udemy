# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv(r"C:\Users\User\Documents\GitHub\Complete-Data-Science-and-Machine-Learning-Bootcamp-Udemy\section_2\data\cost_revenue_clean.csv")
data.describe()
# Out:
#        Production_Budget_USD  Worldwide_Gross_USD
# count           5.391000e+03         5.391000e+03
# mean            3.111374e+07         8.885542e+07
# std             4.052380e+07         1.684578e+08
# min             1.100000e+03         0.000000e+00
# 25%             5.000000e+06         3.865206e+06
# 50%             1.700000e+07         2.745045e+07
# 75%             4.000000e+07         9.645446e+07
# max             4.250000e+08         2.783919e+09

# %%
X = pd.DataFrame(data, columns=['Production_Budget_USD'])
y = pd.DataFrame(data, columns=['Worldwide_Gross_USD'])

# %%
X
# Out:
#       Production_Budget_USD
# 0                  110000.0
# 1                  385907.0
# 2                  200000.0
# 3                  100000.0
# 4                  245000.0
# ...                     ...
# 5386             15000000.0
# 5387            160000000.0
# 5388            175000000.0
# 5389             50000000.0
# 5390             20000000.0
#
# [5391 rows x 1 columns]

# %%
plt.figure(figsize = (10,6))
plt.scatter(X,y, alpha = 0.3)
plt.title('Movie Cost v/s Global Revenues')
plt.xlabel('Production Budget USD')
plt.ylabel('Worldwide Gross USD')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000 )
plt.show()

# %%
regression = LinearRegression()
regression.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Slope Coefficient

# %%
regression.coef_ # Theta_1
# Out:
# array([[3.08949319]])

# %%
# Intercept
regression.intercept_
# Out:
# array([-7270258.41995637])

# %%
plt.figure(figsize = (10,6))
plt.scatter(X,y, alpha = 0.3)
plt.plot(X,regression.predict(X), color = "red", linewidth = 4)
plt.title('Movie Cost v/s Global Revenues')
plt.xlabel('Production Budget USD')
plt.ylabel('Worldwide Gross USD')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000 )
plt.show()
